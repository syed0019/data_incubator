# %% [markdown]
# # Arrest_Data_from_2010_to_Present

# %% [markdown]
# ## Section 1

# %%
import numpy as np

import pandas as pd

df = pd.read_csv('Arrest_Data_from_2010_to_Present.csv')

df.head()
# Out:
#    Report ID Arrest Date    Time  Area ID  Area Name  Reporting District  Age  \
# 0  191811472  05/03/2019  1700.0       18  Southeast                1802   23
# 1    5614161  04/29/2019  1040.0        8    West LA                 842   41
# 2    5615197  04/30/2019   615.0        6  Hollywood                 663   27
# 3    5615701  04/30/2019  1100.0        9   Van Nuys                 901    2
# 4    5615929  04/30/2019  1550.0       20    Olympic                2049   41
#
#   Sex Code Descent Code  Charge Group Code Charge Group Description  \
# 0        F            B                NaN                      NaN
# 1        M            H                3.0                  Robbery
# 2        M            O                5.0                 Burglary
# 3        F            H                NaN                      NaN
# 4        M            W                4.0       Aggravated Assault
#
#   Arrest Type Code       Charge Charge Description  \
# 0                M    653.22 PC                NaN
# 1                F        211PC            ROBBERY
# 2                F        459PC           BURGLARY
# 3                D    300(B)WIC                NaN
# 4                F  245(A)(2)PC      ADW W/FIREARM
#
#                                     Address                     Cross Street  \
# 0                                      91ST                         FIGUEROA
# 1  11600    WILSHIRE                     BL                              NaN
# 2                                   LA BREA                        LEXINGTON
# 3                                    RAYMER  SEPULVEDA                    BL
# 4           8TH                          ST                          VERMONT
#
#                Location
# 0  (33.9543, -118.2827)
# 1  (34.0508, -118.4592)
# 2  (34.0907, -118.3384)
# 3  (34.2149, -118.4674)
# 4  (34.0578, -118.2916)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1310127 entries, 0 to 1310126
# Data columns (total 17 columns):
# Report ID                   1310127 non-null int64
# Arrest Date                 1310127 non-null object
# Time                        1309932 non-null float64
# Area ID                     1310127 non-null int64
# Area Name                   1310127 non-null object
# Reporting District          1310127 non-null int64
# Age                         1310127 non-null int64
# Sex Code                    1310127 non-null object
# Descent Code                1310127 non-null object
# Charge Group Code           1222098 non-null float64
# Charge Group Description    1221577 non-null object
# Arrest Type Code            1310127 non-null object
# Charge                      1310127 non-null object
# Charge Description          1222140 non-null object
# Address                     1310127 non-null object
# Cross Street                747661 non-null object
# Location                    1310127 non-null object
# dtypes: float64(2), int64(4), object(11)
# memory usage: 169.9+ MB

# %%
cols = ['Sex Code', 'Descent Code']

# %%
df[cols] = df[cols].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1310127 entries, 0 to 1310126
# Data columns (total 17 columns):
# Report ID                   1310127 non-null int64
# Arrest Date                 1310127 non-null object
# Time                        1309932 non-null float64
# Area ID                     1310127 non-null int64
# Area Name                   1310127 non-null object
# Reporting District          1310127 non-null int64
# Age                         1310127 non-null int64
# Sex Code                    1310127 non-null category
# Descent Code                1310127 non-null category
# Charge Group Code           1222098 non-null float64
# Charge Group Description    1221577 non-null object
# Arrest Type Code            1310127 non-null object
# Charge                      1310127 non-null object
# Charge Description          1222140 non-null object
# Address                     1310127 non-null object
# Cross Street                747661 non-null object
# Location                    1310127 non-null object
# dtypes: category(2), float64(2), int64(4), object(9)
# memory usage: 152.4+ MB

# %%
df['Arrest Date'] = df['Arrest Date'].astype('datetime64[ns]')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1310127 entries, 0 to 1310126
# Data columns (total 17 columns):
# Report ID                   1310127 non-null int64
# Arrest Date                 1310127 non-null datetime64[ns]
# Time                        1309932 non-null float64
# Area ID                     1310127 non-null int64
# Area Name                   1310127 non-null object
# Reporting District          1310127 non-null int64
# Age                         1310127 non-null int64
# Sex Code                    1310127 non-null category
# Descent Code                1310127 non-null category
# Charge Group Code           1222098 non-null float64
# Charge Group Description    1221577 non-null object
# Arrest Type Code            1310127 non-null object
# Charge                      1310127 non-null object
# Charge Description          1222140 non-null object
# Address                     1310127 non-null object
# Cross Street                747661 non-null object
# Location                    1310127 non-null object
# dtypes: category(2), datetime64[ns](1), float64(2), int64(4), object(8)
# memory usage: 152.4+ MB

# %%
df.head(2)
# Out:
#    Report ID Arrest Date    Time  Area ID  Area Name  Reporting District  Age  \
# 0  191811472  2019-05-03  1700.0       18  Southeast                1802   23
# 1    5614161  2019-04-29  1040.0        8    West LA                 842   41
#
#   Sex Code Descent Code  Charge Group Code Charge Group Description  \
# 0        F            B                NaN                      NaN
# 1        M            H                3.0                  Robbery
#
#   Arrest Type Code     Charge Charge Description  \
# 0                M  653.22 PC                NaN
# 1                F      211PC            ROBBERY
#
#                                     Address Cross Street              Location
# 0                                      91ST     FIGUEROA  (33.9543, -118.2827)
# 1  11600    WILSHIRE                     BL          NaN  (34.0508, -118.4592)

# %%
# filling missing values

list_of_cols = ['Time','Charge Group Code','Charge Group Description','Charge Description', 'Cross Street']

df[list_of_cols] = df[list_of_cols].fillna('NaN')

df.count()
# Out:
# Report ID                   1310127
# Arrest Date                 1310127
# Time                        1310127
# Area ID                     1310127
# Area Name                   1310127
# Reporting District          1310127
# Age                         1310127
# Sex Code                    1310127
# Descent Code                1310127
# Charge Group Code           1310127
# Charge Group Description    1310127
# Arrest Type Code            1310127
# Charge                      1310127
# Charge Description          1310127
# Address                     1310127
# Cross Street                1310127
# Location                    1310127
# dtype: int64

# %%
(df['Cross Street'] == 'NaN').value_counts()
# Out:
# False    747661
# True     562466
# Name: Cross Street, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1310127 entries, 0 to 1310126
# Data columns (total 17 columns):
# Report ID                   1310127 non-null int64
# Arrest Date                 1310127 non-null datetime64[ns]
# Time                        1310127 non-null object
# Area ID                     1310127 non-null int64
# Area Name                   1310127 non-null object
# Reporting District          1310127 non-null int64
# Age                         1310127 non-null int64
# Sex Code                    1310127 non-null category
# Descent Code                1310127 non-null category
# Charge Group Code           1310127 non-null object
# Charge Group Description    1310127 non-null object
# Arrest Type Code            1310127 non-null category
# Charge                      1310127 non-null object
# Charge Description          1310127 non-null object
# Address                     1310127 non-null object
# Cross Street                1310127 non-null object
# Location                    1310127 non-null object
# dtypes: category(3), datetime64[ns](1), int64(4), object(9)
# memory usage: 143.7+ MB

# %%
start_date = '2018/01/01'
end_date = '2018/12/31'

# %%
filter_ = (df['Arrest Date'] >= start_date) & (df['Arrest Date'] <= end_date)

# %%
# 1. Answer

df.loc[filter_].count()
# Out:
# Report ID                   104277
# Arrest Date                 104277
# Time                        104277
# Area ID                     104277
# Area Name                   104277
# Reporting District          104277
# Age                         104277
# Sex Code                    104277
# Descent Code                104277
# Charge Group Code           104277
# Charge Group Description    104277
# Arrest Type Code            104277
# Charge                      104277
# Charge Description          104277
# Address                     104277
# Cross Street                104277
# Location                    104277
# dtype: int64

# %%
# 2. Answer

df.loc[filter_]['Area Name'].value_counts()
# Out:
# Central        10951
# Hollywood       9715
# Rampart         7345
# Pacific         6778
# 77th Street     6259
# Van Nuys        6193
# Southwest       5927
# Newton          5427
# N Hollywood     4947
# Mission         4357
# Olympic         3898
# Harbor          3875
# Southeast       3601
# Hollenbeck      3590
# West Valley     3562
# Northeast       3452
# Devonshire      3146
# Topanga         3094
# Foothill        3006
# West LA         2687
# Wilshire        2467
# Name: Area Name, dtype: int64

# %%
list_of_charge_groups = ['Vehicle Theft','Robbery','Burglary','Receive Stolen Property']

charge_groups = df['Charge Group Description'].str.contains('|'.join(list_of_charge_groups), na=False)

df.loc[filter_]['Age'][charge_groups].describe()
# Out:
# count    8457.000000
# mean       29.189902
# std        10.661333
# min        10.000000
# 25%        21.000000
# 50%        27.000000
# 75%        35.000000
# max        73.000000
# Name: Age, dtype: float64

# %%
# verification of quantiles

df.loc[filter_]['Age'][charge_groups].quantile([.25,.5,.75])
# Out:
# 0.25    21.0
# 0.50    27.0
# 0.75    35.0
# Name: Age, dtype: float64

# %%
# 3. Answer

df.loc[filter_]['Age'][charge_groups].quantile(.95)
# Out:
# 52.0

# %%
from scipy import stats

# excluding charges related to minor and unknown

revised_charge_groups = df['Charge Group Description'].str.replace(
    r'Pre-Delinquency, Non-Criminal Detention','').str.contains('',na=False)

data_to_use = pd.to_numeric(df.loc[filter_]['Age'][revised_charge_groups])

# %%
stats.zscore(data_to_use)
# Out:
# array([-0.46945912, -0.16434844,  0.67470594, ..., -0.77456981,
#        -0.92712515, -0.54573679])

# %%
# 4. Answer

abs(stats.zscore(data_to_use)).max()
# Out:
# 4.33603415025992

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.head(2)
# Out:
#    Report ID Arrest Date  Time  Area ID  Area Name  Reporting District  Age  \
# 0  191811472  2019-05-03  1700       18  Southeast                1802   23
# 1    5614161  2019-04-29  1040        8    West LA                 842   41
#
#   Sex Code Descent Code Charge Group Code Charge Group Description  \
# 0        F            B               NaN                      NaN
# 1        M            H                 3                  Robbery
#
#   Arrest Type Code     Charge Charge Description  \
# 0                M  653.22 PC                NaN
# 1                F      211PC            ROBBERY
#
#                                     Address Cross Street              Location
# 0                                      91ST     FIGUEROA  (33.9543, -118.2827)
# 1  11600    WILSHIRE                     BL          NaN  (34.0508, -118.4592)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1310127, step=1)

# %%
new_df = df.set_index('Arrest Date')

# %%
new_df.index
# Out:
# DatetimeIndex(['2019-05-03', '2019-04-29', '2019-04-30', '2019-04-30',
#                '2019-04-30', '2019-04-16', '2019-04-26', '2019-04-26',
#                '2019-04-26', '2019-04-27',
#                ...
#                '2019-04-27', '2019-04-27', '2019-04-27', '2019-04-27',
#                '2019-04-27', '2019-04-27', '2019-04-27', '2019-04-27',
#                '2019-04-27', '2019-04-27'],
#               dtype='datetime64[ns]', name='Arrest Date', length=1310127, freq=None)

# %%
new_df.head(1)
# Out:
#              Report ID  Time  Area ID  Area Name  Reporting District  Age  \
# Arrest Date
# 2019-05-03   191811472  1700       18  Southeast                1802   23
#
#             Sex Code Descent Code Charge Group Code Charge Group Description  \
# Arrest Date
# 2019-05-03         F            B               NaN                      NaN
#
#             Arrest Type Code     Charge Charge Description Address  \
# Arrest Date
# 2019-05-03                 M  653.22 PC                NaN    91ST
#
#             Cross Street              Location
# Arrest Date
# 2019-05-03      FIGUEROA  (33.9543, -118.2827)

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1310127 entries, 2019-05-03 to 2019-04-27
# Data columns (total 16 columns):
# Report ID                   1310127 non-null int64
# Time                        1310127 non-null object
# Area ID                     1310127 non-null int64
# Area Name                   1310127 non-null object
# Reporting District          1310127 non-null int64
# Age                         1310127 non-null int64
# Sex Code                    1310127 non-null category
# Descent Code                1310127 non-null category
# Charge Group Code           1310127 non-null object
# Charge Group Description    1310127 non-null object
# Arrest Type Code            1310127 non-null object
# Charge                      1310127 non-null object
# Charge Description          1310127 non-null object
# Address                     1310127 non-null object
# Cross Street                1310127 non-null object
# Location                    1310127 non-null object
# dtypes: category(2), int64(4), object(10)
# memory usage: 152.4+ MB

# %%
df_all_arrests_code = new_df[['Arrest Type Code']]
df_all_arrests_code
# Out:
#             Arrest Type Code
# Arrest Date
# 2019-05-03                 M
# 2019-04-29                 F
# 2019-04-30                 F
# 2019-04-30                 D
# 2019-04-30                 F
# 2019-04-16                 M
# 2019-04-26                 M
# 2019-04-26                 M
# 2019-04-26                 M
# 2019-04-27                 I
# 2019-04-26                 M
# 2019-04-23                 I
# 2019-04-23                 I
# 2019-04-27                 I
# 2019-04-22                 I
# 2019-04-22                 I
# 2019-04-22                 I
# 2019-04-23                 I
# 2019-04-23                 I
# 2019-04-26                 I
# 2019-04-24                 I
# 2019-04-23                 I
# 2019-04-25                 I
# 2019-04-22                 I
# 2019-04-22                 I
# 2019-04-25                 I
# 2019-04-23                 I
# 2019-04-23                 I
# 2019-04-25                 I
# 2019-04-23                 I
# ...                      ...
# 2010-01-19                 M
# 2017-08-22                 M
# 2010-01-19                 M
# 2010-01-19                 M
# 2010-01-19                 M
# 2010-01-19                 M
# 2010-01-19                 M
# 2017-07-11                 F
# 2010-01-19                 M
# 2017-06-30                 D
# 2010-01-19                 M
# 2014-05-12                 M
# 2010-01-19                 M
# 2010-01-19                 M
# 2013-02-04                 F
# 2010-01-19                 F
# 2013-10-15                 F
# 2010-01-19                 M
# 2019-04-27                 M
# 2019-04-27                 M
# 2019-04-27                 M
# 2019-04-27                 M
# 2019-04-27                 F
# 2019-04-27                 F
# 2019-04-27                 M
# 2019-04-27                 M
# 2019-04-27                 F
# 2019-04-27                 F
# 2019-04-27                 F
# 2019-04-27                 F
#
# [1310127 rows x 1 columns]

# %%
felony_arrests = df_all_arrests_code[df_all_arrests_code['Arrest Type Code'] == 'F']['2010':'2018'].resample('A').count()

felony_arrests
# Out:
#              Arrest Type Code
# Arrest Date
# 2010-12-31              51157
# 2011-12-31              49830
# 2012-12-31              50610
# 2013-12-31              47882
# 2014-12-31              45878
# 2015-12-31              35709
# 2016-12-31              36880
# 2017-12-31              35974
# 2018-12-31              34948

# %%
felony_arrests.plot(title='Felony Arrests (2010-2018)',marker='D')
plt.xlabel('Year')
plt.ylabel('Number of Arrests')
plt.legend()
plt.show()

# %%
# 5. Answer

predicted_felony_arrest_2019 = int(felony_arrests.mean())

predicted_felony_arrest_2019
# Out:
# 43207

# %%
new_df.head(2)
# Out:
#              Report ID    Time  Area ID  Area Name  Reporting District  Age  \
# Arrest Date
# 2019-05-03   191811472  1700.0       18  Southeast                1802   23
# 2019-04-29     5614161  1040.0        8    West LA                 842   41
#
#             Sex Code Descent Code  Charge Group Code Charge Group Description  \
# Arrest Date
# 2019-05-03         F            B                NaN                      NaN
# 2019-04-29         M            H                3.0                  Robbery
#
#             Arrest Type Code     Charge Charge Description  \
# Arrest Date
# 2019-05-03                 M  653.22 PC                NaN
# 2019-04-29                 F      211PC            ROBBERY
#
#                                               Address Cross Street  \
# Arrest Date
# 2019-05-03                                       91ST     FIGUEROA
# 2019-04-29   11600    WILSHIRE                     BL          NaN
#
#                          Location
# Arrest Date
# 2019-05-03   (33.9543, -118.2827)
# 2019-04-29   (34.0508, -118.4592)

# %%
dir(math)
# Out:
# ['__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'ceil',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'pi',
#  'pow',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc']

# %%
Location_coordinates = new_df[['Location']]
Location_coordinates
# Out:
#                          Location
# Arrest Date
# 2019-05-03   (33.9543, -118.2827)
# 2019-04-29   (34.0508, -118.4592)
# 2019-04-30   (34.0907, -118.3384)
# 2019-04-30   (34.2149, -118.4674)
# 2019-04-30   (34.0578, -118.2916)
# 2019-04-16    (34.053, -118.2444)
# 2019-04-26   (34.0481, -118.2542)
# 2019-04-26   (34.0514, -118.2451)
# 2019-04-26    (34.048, -118.2577)
# 2019-04-27   (34.0438, -118.2547)
# 2019-04-26   (34.0552, -118.2322)
# 2019-04-23   (34.0562, -118.2673)
# 2019-04-23   (34.0601, -118.2761)
# 2019-04-27   (34.0601, -118.2761)
# 2019-04-22   (34.0597, -118.2795)
# 2019-04-22   (34.0597, -118.2795)
# 2019-04-22   (34.0597, -118.2795)
# 2019-04-23   (34.0601, -118.2761)
# 2019-04-23   (34.0601, -118.2761)
# 2019-04-26   (34.0569, -118.2689)
# 2019-04-24   (34.0596, -118.2749)
# 2019-04-23   (34.0691, -118.2759)
# 2019-04-25   (34.0498, -118.2754)
# 2019-04-22   (34.0601, -118.2761)
# 2019-04-22   (34.0601, -118.2761)
# 2019-04-25   (34.0601, -118.2761)
# 2019-04-23   (34.0601, -118.2761)
# 2019-04-23   (34.0601, -118.2761)
# 2019-04-25   (34.0601, -118.2761)
# 2019-04-23   (34.0601, -118.2761)
# ...                           ...
# 2010-01-19    (34.048, -118.4626)
# 2017-08-22   (34.1209, -118.2729)
# 2010-01-19   (34.0456, -118.4519)
# 2010-01-19   (33.9775, -118.4292)
# 2010-01-19   (34.0406, -118.4633)
# 2010-01-19    (34.0404, -118.377)
# 2010-01-19   (34.0536, -118.4655)
# 2017-07-11   (34.0524, -118.2467)
# 2010-01-19   (33.9454, -118.3701)
# 2017-06-30   (34.1137, -118.2353)
# 2010-01-19   (34.0452, -118.4529)
# 2014-05-12   (34.1665, -118.5859)
# 2010-01-19   (34.0477, -118.4581)
# 2010-01-19    (34.0404, -118.377)
# 2013-02-04   (33.7577, -118.2884)
# 2010-01-19   (34.0161, -118.3547)
# 2013-10-15   (34.2061, -118.3823)
# 2010-01-19   (34.0546, -118.3953)
# 2019-04-27   (34.2157, -118.3848)
# 2019-04-27    (34.0382, -118.284)
# 2019-04-27   (34.0473, -118.2601)
# 2019-04-27   (34.2076, -118.4287)
# 2019-04-27   (34.0499, -118.2033)
# 2019-04-27   (34.2121, -118.3878)
# 2019-04-27    (33.778, -118.2727)
# 2019-04-27   (34.2156, -118.5975)
# 2019-04-27   (34.0483, -118.2631)
# 2019-04-27   (34.2248, -118.4967)
# 2019-04-27    (33.942, -118.2739)
# 2019-04-27   (33.9994, -118.3108)
#
# [1310127 rows x 1 columns]

# %%
(Location_coordinates['Location'] == '(0,0)').value_counts()
# Out:
# False    1310127
# Name: Location, dtype: int64

# %%
old_coordinates = ('34.050536, -118.247861')
new_longitude = ('34.41140, -118.148717') # calculated online using "http://edwilliams.org/gccalc.htm"

# %%
# 6. Answer

arrests_within_2km_2018 = Location_coordinates[(Location_coordinates['Location'] >= '(34.050536, -118.247861)') &
                                               (Location_coordinates['Location'] <= '(34.41140, -118.148717)')]['2018'].count()

arrests_within_2km_2018
# Out:
# Location    56885
# dtype: int64

# %%
new_df.head()
# Out:
#              Report ID    Time  Area ID  Area Name  Reporting District  Age  \
# Arrest Date
# 2019-05-03   191811472  1700.0       18  Southeast                1802   23
# 2019-04-29     5614161  1040.0        8    West LA                 842   41
# 2019-04-30     5615197   615.0        6  Hollywood                 663   27
# 2019-04-30     5615701  1100.0        9   Van Nuys                 901    2
# 2019-04-30     5615929  1550.0       20    Olympic                2049   41
#
#             Sex Code Descent Code  Charge Group Code Charge Group Description  \
# Arrest Date
# 2019-05-03         F            B                NaN                      NaN
# 2019-04-29         M            H                3.0                  Robbery
# 2019-04-30         M            O                5.0                 Burglary
# 2019-04-30         F            H                NaN                      NaN
# 2019-04-30         M            W                4.0       Aggravated Assault
#
#             Arrest Type Code       Charge Charge Description  \
# Arrest Date
# 2019-05-03                 M    653.22 PC                NaN
# 2019-04-29                 F        211PC            ROBBERY
# 2019-04-30                 F        459PC           BURGLARY
# 2019-04-30                 D    300(B)WIC                NaN
# 2019-04-30                 F  245(A)(2)PC      ADW W/FIREARM
#
#                                               Address  \
# Arrest Date
# 2019-05-03                                       91ST
# 2019-04-29   11600    WILSHIRE                     BL
# 2019-04-30                                    LA BREA
# 2019-04-30                                     RAYMER
# 2019-04-30            8TH                          ST
#
#                                 Cross Street              Location
# Arrest Date
# 2019-05-03                          FIGUEROA  (33.9543, -118.2827)
# 2019-04-29                               NaN  (34.0508, -118.4592)
# 2019-04-30                         LEXINGTON  (34.0907, -118.3384)
# 2019-04-30   SEPULVEDA                    BL  (34.2149, -118.4674)
# 2019-04-30                           VERMONT  (34.0578, -118.2916)

# %%
pico_arrest_2018 = new_df[new_df['Address'] == 'PICO']['2018']

pico_arrest_2018.head(2)
# Out:
#              Report ID  Time  Area ID Area Name  Reporting District  Age  \
# Arrest Date
# 2018-09-15   182017311  2200       20   Olympic                2079   18
# 2018-09-09     5418301  2205        1   Central                 182   42
#
#             Sex Code Descent Code Charge Group Code Charge Group Description  \
# Arrest Date
# 2018-09-15         M            H                16       Narcotic Drug Laws
# 2018-09-09         M            B                10       Fraud/Embezzlement
#
#             Arrest Type Code      Charge  \
# Arrest Date
# 2018-09-15                 M  11357(A)HS
# 2018-09-09                 F   4463(A)VC
#
#                                 Charge Description Address  \
# Arrest Date
# 2018-09-15           POSSESS CONCENTRATED CANNABIS    PICO
# 2018-09-09   ALTER REGISTRATION/LICENSE PLATES/ETC    PICO
#
#                                 Cross Street              Location
# Arrest Date
# 2018-09-15   WESTMORELAND                 AV  (34.0473, -118.2891)
# 2018-09-09                              MAIN   (34.042, -118.2625)

# %%
# length of 'Pico Boulevard' taken online from "https://en.wikipedia.org/wiki/Pico_Boulevard"

pico_blvd_length_km = 3

len(pico_arrest_2018)
# Out:
# 301

# %%
# 7. Answer

per_km_arrests_pico_2018 = int(len(pico_arrest_2018)/pico_blvd_length)

per_km_arrests_pico_2018
# Out:
# 100

# %%
new_df = df.set_index('Arrest Date')

new_df.head()
# Out:
#              Report ID  Time  Area ID  Area Name  Reporting District  Age  \
# Arrest Date
# 2019-05-03   191811472  1700       18  Southeast                1802   23
# 2019-04-29     5614161  1040        8    West LA                 842   41
# 2019-04-30     5615197   615        6  Hollywood                 663   27
# 2019-04-30     5615701  1100        9   Van Nuys                 901    2
# 2019-04-30     5615929  1550       20    Olympic                2049   41
#
#             Sex Code Descent Code Charge Group Code Charge Group Description  \
# Arrest Date
# 2019-05-03         F            B               NaN                      NaN
# 2019-04-29         M            H                 3                  Robbery
# 2019-04-30         M            O                 5                 Burglary
# 2019-04-30         F            H               NaN                      NaN
# 2019-04-30         M            W                 4       Aggravated Assault
#
#             Arrest Type Code       Charge Charge Description  \
# Arrest Date
# 2019-05-03                 M    653.22 PC                NaN
# 2019-04-29                 F        211PC            ROBBERY
# 2019-04-30                 F        459PC           BURGLARY
# 2019-04-30                 D    300(B)WIC                NaN
# 2019-04-30                 F  245(A)(2)PC      ADW W/FIREARM
#
#                                               Address  \
# Arrest Date
# 2019-05-03                                       91ST
# 2019-04-29   11600    WILSHIRE                     BL
# 2019-04-30                                    LA BREA
# 2019-04-30                                     RAYMER
# 2019-04-30            8TH                          ST
#
#                                 Cross Street              Location
# Arrest Date
# 2019-05-03                          FIGUEROA  (33.9543, -118.2827)
# 2019-04-29                               NaN  (34.0508, -118.4592)
# 2019-04-30                         LEXINGTON  (34.0907, -118.3384)
# 2019-04-30   SEPULVEDA                    BL  (34.2149, -118.4674)
# 2019-04-30                           VERMONT  (34.0578, -118.2916)

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1310127 entries, 2019-05-03 to 2019-04-27
# Data columns (total 16 columns):
# Report ID                   1310127 non-null int64
# Time                        1310127 non-null object
# Area ID                     1310127 non-null int64
# Area Name                   1310127 non-null object
# Reporting District          1310127 non-null int64
# Age                         1310127 non-null int64
# Sex Code                    1310127 non-null category
# Descent Code                1310127 non-null category
# Charge Group Code           1310127 non-null object
# Charge Group Description    1310127 non-null object
# Arrest Type Code            1310127 non-null object
# Charge                      1310127 non-null object
# Charge Description          1310127 non-null object
# Address                     1310127 non-null object
# Cross Street                1310127 non-null object
# Location                    1310127 non-null object
# dtypes: category(2), int64(4), object(10)
# memory usage: 152.4+ MB

# %%
df_charge_codes = new_df[['Area ID','Charge Group Code','Charge Group Description']]

df_charge_codes.head()
# Out:
#              Area ID Charge Group Code Charge Group Description
# Arrest Date
# 2019-05-03        18               NaN                      NaN
# 2019-04-29         8                 3                  Robbery
# 2019-04-30         6                 5                 Burglary
# 2019-04-30         9               NaN                      NaN
# 2019-04-30        20                 4       Aggravated Assault

# %%
df_charge_codes['Charge Group Code'] = df_charge_codes['Charge Group Code'].astype(float)
# Out:
# C:\Users\ABC\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_charge_codes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1310127 entries, 2019-05-03 to 2019-04-27
# Data columns (total 3 columns):
# Area ID                     1310127 non-null int64
# Charge Group Code           1222098 non-null float64
# Charge Group Description    1310127 non-null object
# dtypes: float64(1), int64(1), object(1)
# memory usage: 40.0+ MB

# %%
df_2018 = df_charge_codes['2018']

# %%
df_2018.head()
# Out:
#              Area ID  Charge Group Code Charge Group Description
# Arrest Date
# 2018-01-24         6               10.0       Fraud/Embezzlement
# 2018-03-15         7                1.0                 Homicide
# 2018-06-01         3               16.0       Narcotic Drug Laws
# 2018-06-10        13               12.0      Weapon (carry/poss)
# 2018-07-07        18               12.0      Weapon (carry/poss)

# %%
grouped_df = df_2018.groupby('Charge Group Description')[['Charge Group Code','Area ID']].mean()
grouped_df
# Out:
#                                 Charge Group Code    Area ID
# Charge Group Description
# Against Family/Child                    15.000000  11.253521
# Aggravated Assault                       4.000000  10.519120
# Burglary                                 5.000000  10.269152
# Disorderly Conduct                      20.000000   4.675079
# Disturbing the Peace                    19.000000   9.836735
# Driving Under Influence                 22.000000  11.211258
# Drunkeness                              18.000000   8.333510
# Federal Offenses                        25.000000  11.360000
# Forgery/Counterfeit                      9.000000   9.296386
# Fraud/Embezzlement                      10.000000  10.893497
# Gambling                                21.000000  13.342857
# Homicide                                 1.000000  11.145985
# Larceny                                  6.000000  10.214077
# Liquor Laws                             17.000000   6.513071
# Miscellaneous Other Violations          24.000000   9.505963
# Moving Traffic Violations               23.000000  10.040393
# NaN                                     30.842105   8.480061
# Narcotic Drug Laws                      16.000000   9.438067
# Non-Criminal Detention                  26.000000  11.883838
# Other Assaults                           8.000000  10.160364
# Pre-Delinquency                         27.000000  12.041667
# Prostitution/Allied                     13.000000  11.551852
# Rape                                     2.000000  10.015873
# Receive Stolen Property                 11.000000   9.747253
# Robbery                                  3.000000  10.025117
# Sex (except rape/prst)                  14.000000   9.824427
# Vehicle Theft                            7.000000  11.343261
# Weapon (carry/poss)                     12.000000  10.679918

# %%
grouped_df['area_to_charge_ratio'] = grouped_df['Area ID'] / grouped_df['Charge Group Code']

# %%
grouped_df.head()
# Out:
#                           Charge Group Code    Area ID  charge_to_area_ratio  \
# Charge Group Description
# Against Family/Child                   15.0  11.253521              1.332916
# Aggravated Assault                      4.0  10.519120              0.380260
# Burglary                                5.0  10.269152              0.486895
# Disorderly Conduct                     20.0   4.675079              4.278003
# Disturbing the Peace                   19.0   9.836735              1.931535
#
#                           area_to_charge_ratio
# Charge Group Description
# Against Family/Child                  0.750235
# Aggravated Assault                    2.629780
# Burglary                              2.053830
# Disorderly Conduct                    0.233754
# Disturbing the Peace                  0.517723

# %%
total_of_charge_group_code = len(grouped_df['Charge Group Code'])

total_of_charge_group_code
# Out:
# 28

# %%
grouped_df['charge_group_ratio'] = grouped_df['Charge Group Code']/len(grouped_df['Charge Group Code'])

# %%
grouped_df.head()
# Out:
#                           Charge Group Code    Area ID  charge_to_area_ratio  \
# Charge Group Description
# Against Family/Child                   15.0  11.253521              1.332916
# Aggravated Assault                      4.0  10.519120              0.380260
# Burglary                                5.0  10.269152              0.486895
# Disorderly Conduct                     20.0   4.675079              4.278003
# Disturbing the Peace                   19.0   9.836735              1.931535
#
#                           area_to_charge_ratio  charge_group_ratio
# Charge Group Description
# Against Family/Child                  0.750235            0.535714
# Aggravated Assault                    2.629780            0.142857
# Burglary                              2.053830            0.178571
# Disorderly Conduct                    0.233754            0.714286
# Disturbing the Peace                  0.517723            0.678571

# %%
grouped_df['ratio_bw_two_probab'] = grouped_df['area_to_charge_ratio']/grouped_df['charge_group_ratio']

# %%
new_grouped_df = grouped_df.sort_values('ratio_bw_two_probab',ascending=False)

# %%
# 8. Answer

new_grouped_df['ratio_bw_two_probab'].mean()
# Out:
# 17.327115787946692
